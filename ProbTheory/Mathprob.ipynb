# %% [markdown]
# # It was never meant to be working or studying project
# ## This notebook served me as a "quick calculator" during my comprehension of mathematical probability

# %%
from distbuilder import *

# %%
norm_stat_dist(a=-1, sigm=3, x=(-4, 1))
# Out:
# 0.5889

# %% [markdown]
# # Функция распределения случайной величины
#
# ###### doesnt work as it supposed to. Check MatStat version for a working one

# %%
funcs = [
    .25,
    Symbol('x') / 7
]

Fx = build_Fx([0, 7], funcs, mode='fx')

# %%
plot_fx_inf(Fx)

# %%
fx = Fx_to_fx(Fx)

# %%
fx
# Out:
# ([0, [-inf, 0]], [0, [0, 7]], [1/7, [7, inf]])

# %% [markdown]
# # Функция плотности случайной величины

# %%
funcs = [
    1/7, 
    2/5,
    13/14
]

fx = build_Fx(list(range(0, 4)), funcs, mode='Fx')

# %%
plot_fx_inf(fx)
