# %%
import matstat

import numpy as np

# %%
DVS = matstat.discreetVariationSeries
IVS = matstat.intervalVariationSeries

# %%
rng = np.random.default_rng()

# %% [markdown]
# # Discreet series

# %% [markdown]
# ### Building from raw collection of data

# %%
#TODO ws doesnt not sum up to 1

# %%
disc1 = rng.integers(0, 11, 15)

# %%
disc1_dist = DVS(disc1)

# %%
disc1_dist.data
# Out:
#           n     w
# 0       1.0  0.07
# 1       4.0  0.27
# 2       1.0  0.07
# 4       2.0  0.13
# 6       1.0  0.07
# 8       2.0  0.13
# 9       2.0  0.13
# 10      2.0  0.13
# Total  15.0  1.00

# %% [markdown]
# ### Frequency poligon

# %%
disc1_dist.plot_polygon()

# %% [markdown]
# ### Empirical distribution function (Fx)

# %%
disc1_dist.plot_Fx()
# Out:
#  0  , -inf  < x <=   0
# 0.07,   0   < x <=   1
# 0.34,   1   < x <=   2
# 0.41,   2   < x <=   4
# 0.54,   4   < x <=   6
# 0.61,   6   < x <=   8
# 0.74,   8   < x <=   9
# 0.87,   9   < x <=  10
# 1.0 ,  10   < x <=  inf

# %% [markdown]
# ### Building from given distribution

# %%
# TODO: idiotic distribution. make it one list with tuples for this task => [(i, n_i), ...]

# %%
disc2 = np.array([rng.choice(np.arange(0, 10), replace=False, size=(5)), rng.integers(0, 50, 5)])
disc2[0].sort()

# %%
disc2_dist = DVS(disc2)

disc2_dist.data
# Out:
#            n     w
# 0       19.0  0.14
# 1       10.0  0.07
# 2       37.0  0.27
# 8       22.0  0.16
# 9       49.0  0.36
# Total  137.0  1.00

# %% [markdown]
# ### Frequency polygon

# %%
disc2_dist.plot_polygon()

# %% [markdown]
# ### Empirical distribution function (Fx)

# %%
disc2_dist.plot_Fx()
# Out:
#  0  , -inf  < x <=   0
# 0.14,   0   < x <=   1
# 0.21,   1   < x <=   2
# 0.48,   2   < x <=   8
# 0.64,   8   < x <=   9
# 1.0 ,   9   < x <=  inf

# %% [markdown]
# # Interval series

# %% [markdown]
# ### Building from raw collection of data

# %%
cont = rng.logistic(10, 15, size=30)

# %%
ivs = IVS(cont)

# %%
ivs.data
# Out:
#     left   right    x_i  n_i    h_i   w_i  n_i/h  w_i/h
# 0 -45.95  -16.37 -31.16    6  29.58  0.20   0.20   0.01
# 1 -16.37   13.22  -1.58   10  29.58  0.33   0.34   0.01
# 2  13.22   42.80  28.01   12  29.58  0.40   0.41   0.01
# 3  42.80   72.39  57.59    1  29.58  0.03   0.03   0.00
# 4  72.39  101.97  87.18    1  29.58  0.03   0.03   0.00

# %% [markdown]
# ### Frequency polygon

# %%
ivs.plot_polygon()

# %% [markdown]
# ### Empirical distribution function (Fx)

# %%
ivs.plot_Fx()

# %% [markdown]
# ### Frequency histograms

# %%
ivs.plot_hist('x_i', 'n_i/h')

# %%
ivs.plot_hist('x_i', 'w_i/h')

# %% [markdown]
# ### Building from ranges and distribution

# %%
lims = sorted(rng.choice(np.arange(30, 100), replace=False, size=(6)))
ns = rng.choice(np.arange(0, 200), replace=False, size=(5))

# %%
cont_data1 = np.array([(left, right, n) for left, right, n in zip(lims[:-1], lims[1:], ns)])

# %%
ivs1 = IVS(cont_data1)

# %%
ivs1.data
# Out:
#    left  right   x_i  n_i  h_i   w_i  n_i/h  w_i/h
# 0    48     59  53.5   75   11  0.13   6.82   0.01
# 1    59     66  62.5   70    7  0.12  10.00   0.02
# 2    66     70  68.0  193    4  0.33  48.25   0.08
# 3    70     93  81.5  111   23  0.19   4.83   0.01
# 4    93     96  94.5  139    3  0.24  46.33   0.08

# %% [markdown]
# ### Frequency polygon

# %%
ivs1.plot_polygon()

# %% [markdown]
# ### Empirical distribution function (Fx)

# %%
ivs1.plot_Fx()

# %% [markdown]
# ### Frequency histograms

# %%
ivs1.plot_hist('x_i', 'n_i/h')

# %%
ivs1.plot_hist('x_i', 'w_i/h')
